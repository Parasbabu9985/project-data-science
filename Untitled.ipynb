# %%
import pandas as pd
import matplotlib.pyplot as plt
# Looad


df = pd.read_csv('C:/Users/Dell/OneDrive/Desktop/projet data ananlysis data/unemplyment kegal data.csv')



# Clean column names
df.columns = [col.strip().replace(' ', '_').lower() for col in df.columns]

# Clean date
df['date'] = df['date'].str.strip()
df['date'] = pd.to_datetime(df['date'], format='%d-%m-%Y')

# Compute average unemployment per date
overall_trend = (
    df.groupby('date')['estimated_unemployment_rate_(%)']
    .mean()
    .reset_index()
)

# Plot
plt.figure(figsize=(12,6))
sns.lineplot(data=overall_trend, x='date', y='estimated_unemployment_rate_(%)', marker='o')
plt.title('Average Unemployment Rate in India Over Time')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate (%)')
plt.grid(True)
plt.tight_layout()
plt.show()
plt.figure(figsize=(14,8))
sns.lineplot(
    data=df,
    x='date',
    y='estimated_unemployment_rate_(%)',
    hue='region',
    estimator=None,
    alpha=0.7
)
#s
plt.title('Unemployment Rate by State Over Time')
plt.xlabel('Date')
plt.ylabel('Unemployment Rate (%)')
plt.legend(bbox_to_anchor=(1.05,1), loc='upper left')
plt.grid(True)
plt.tight_layout()
plt.show()
# Flag Covid period (from March 2020)
df['covid_period'] = df['date'] >= '2020-03-01'

plt.figure(figsize=(8,6))
sns.boxplot(
    data=df,
    x='covid_period',
    y='estimated_unemployment_rate_(%)'
)
plt.xticks([0,1], ['Pre-Covid', 'Covid'])
plt.title('Unemployment Rate Before vs During Covid-19')
plt.xlabel('')
plt.ylabel('Unemployment Rate (%)')
plt.grid(True)
plt.tight_layout()
plt.show()
